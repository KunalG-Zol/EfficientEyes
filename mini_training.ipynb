# %%
from ultralytics import YOLO

model = YOLO('yolo26n.pt') 

results = model.train(
    data='mini_dataset.yaml', 
    epochs=50, 
    imgsz=512, 
    batch=4,
    name='overfit_test',
    workers=0
)
# Out:
# Ultralytics 8.4.7  Python-3.12.6 torch-2.9.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=mini_dataset.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=512, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=overfit_test7, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\Main Projects\EfficientEyes\runs\detect\overfit_test7, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    241566  ultralytics.nn.modules.head.Detect           [1, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,504,190 parameters, 2,504,190 gradients, 5.8 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 1373.5455.2 MB/s, size: 330.8 KB)
# train: Scanning D:\Main Projects\EfficientEyes\mini_dataset\labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100  0.0s
# val: Fast image access  (ping: 0.10.0 ms, read: 1557.1309.5 MB/s, size: 321.7 KB)
# val: Scanning D:\Main Projects\EfficientEyes\mini_dataset\labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100  0.0s
# Plotting labels to D:\Main Projects\EfficientEyes\runs\detect\overfit_test7\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.002, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 0 dataloader workers
# Logging results to D:\Main Projects\EfficientEyes\runs\detect\overfit_test7
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      0.58G      2.059       5.42   0.009891         23        512: 100% ━━━━━━━━━━━━ 25/25 2.9it/s 8.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 4.5it/s 2.9s0.1s
#                    all        100        291    0.00277      0.285    0.00203   0.000722
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50     0.604G      1.977      5.412   0.009125         18        512: 100% ━━━━━━━━━━━━ 25/25 4.8it/s 5.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 9.0it/s 1.4s0.1s
#                    all        100        291     0.0029      0.299    0.00229   0.000953
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50     0.604G      1.847      5.289   0.009213         16        512: 100% ━━━━━━━━━━━━ 25/25 5.6it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 8.8it/s 1.5s0.1s
#                    all        100        291    0.00367      0.378    0.00334    0.00142
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50     0.604G      1.776        5.1   0.008569          7        512: 100% ━━━━━━━━━━━━ 25/25 5.9it/s 4.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 8.9it/s 1.5s0.1s
#                    all        100        291    0.00423      0.436    0.00456    0.00205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50     0.604G       1.84      5.105    0.00885         14        512: 100% ━━━━━━━━━━━━ 25/25 5.4it/s 4.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 8.3it/s 1.6s0.1s
#                    all        100        291    0.00517      0.533    0.00839    0.00444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50     0.604G       1.61      4.687   0.006983         10        512: 100% ━━━━━━━━━━━━ 25/25 5.4it/s 4.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 8.6it/s 1.5s0.1s
#                    all        100        291    0.00713      0.735     0.0689     0.0371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50     0.604G      1.652       4.41    0.00668         18        512: 100% ━━━━━━━━━━━━ 25/25 5.6it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.6it/s 1.7s0.1s
#                    all        100        291      0.564     0.0357      0.199      0.115
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50     0.604G      1.611      4.308   0.007133         16        512: 100% ━━━━━━━━━━━━ 25/25 4.7it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.0it/s 1.8s0.2s
#                    all        100        291      0.365      0.292      0.261      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50     0.604G      1.468      4.611    0.00683         10        512: 100% ━━━━━━━━━━━━ 25/25 4.3it/s 5.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.1it/s 2.1s0.2s
#                    all        100        291      0.344      0.357      0.275      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50     0.604G      1.384      4.746   0.006086         20        512: 100% ━━━━━━━━━━━━ 25/25 4.3it/s 5.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.9it/s 2.2s0.2s
#                    all        100        291      0.335      0.378      0.299      0.195
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50     0.604G      1.436      3.872   0.006832         14        512: 100% ━━━━━━━━━━━━ 25/25 4.1it/s 6.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.2it/s 2.1s0.2s
#                    all        100        291       0.37      0.357      0.299      0.196
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50     0.604G      1.526      3.909   0.006489         18        512: 100% ━━━━━━━━━━━━ 25/25 3.9it/s 6.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.6it/s 2.0s0.1s
#                    all        100        291      0.418      0.354      0.328      0.222
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50     0.604G      1.427      4.042   0.006981          7        512: 100% ━━━━━━━━━━━━ 25/25 4.2it/s 6.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.3it/s 2.1s0.2s
#                    all        100        291      0.426      0.351      0.341      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50     0.604G        1.5       3.71   0.005988         11        512: 100% ━━━━━━━━━━━━ 25/25 4.2it/s 5.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.1it/s 1.8s0.1s
#                    all        100        291      0.446      0.375      0.376      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50     0.604G        1.4      3.537   0.006031          9        512: 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.4it/s 1.8s0.1s
#                    all        100        291      0.518      0.354      0.401      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50     0.604G      1.534       3.52   0.006397         11        512: 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.7it/s 1.7s0.1s
#                    all        100        291      0.526      0.371      0.414      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50     0.604G      1.447      3.151   0.005908         14        512: 100% ━━━━━━━━━━━━ 25/25 4.8it/s 5.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 8.0it/s 1.6s0.1s
#                    all        100        291      0.516      0.385      0.422      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50     0.604G      1.324      2.981   0.005568         15        512: 100% ━━━━━━━━━━━━ 25/25 5.3it/s 4.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 8.0it/s 1.6s0.1s
#                    all        100        291       0.52      0.378      0.427      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50     0.604G      1.363      3.065   0.005688         24        512: 100% ━━━━━━━━━━━━ 25/25 4.3it/s 5.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.4it/s 1.7s0.1s
#                    all        100        291      0.441      0.499      0.462      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50     0.604G      1.447      2.975   0.005828         16        512: 100% ━━━━━━━━━━━━ 25/25 4.7it/s 5.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.8it/s 1.7s0.1s
#                    all        100        291      0.499      0.509      0.494      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50     0.611G       1.41      2.799   0.006209         12        512: 100% ━━━━━━━━━━━━ 25/25 4.8it/s 5.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.4it/s 1.8s0.1s
#                    all        100        291      0.558       0.56      0.535      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50     0.611G      1.327       3.04   0.006483         13        512: 100% ━━━━━━━━━━━━ 25/25 4.7it/s 5.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.4it/s 1.8s0.1s
#                    all        100        291      0.673      0.517       0.58      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50     0.611G      1.327      2.413    0.00541         17        512: 100% ━━━━━━━━━━━━ 25/25 5.0it/s 5.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.0it/s 1.9s0.2s
#                    all        100        291      0.691      0.543      0.584      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50     0.611G      1.372      2.728   0.005479         20        512: 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.9it/s 1.9s0.1s
#                    all        100        291      0.638      0.533      0.589      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50     0.611G       1.28       2.84   0.005236          6        512: 100% ━━━━━━━━━━━━ 25/25 5.1it/s 4.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.7it/s 1.7s0.1s
#                    all        100        291      0.641       0.55      0.601      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50     0.611G      1.406      2.721   0.006363         25        512: 100% ━━━━━━━━━━━━ 25/25 4.7it/s 5.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.8it/s 1.7s0.1s
#                    all        100        291      0.658      0.567      0.623       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50     0.611G      1.382      2.719   0.006162          8        512: 100% ━━━━━━━━━━━━ 25/25 5.1it/s 4.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.6it/s 1.7s0.1s
#                    all        100        291      0.667      0.557      0.624       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50     0.611G      1.373      2.257   0.005718         11        512: 100% ━━━━━━━━━━━━ 25/25 4.6it/s 5.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.9it/s 1.9s0.2s
#                    all        100        291       0.63      0.608      0.631      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50     0.611G      1.381      2.287    0.00588         21        512: 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.2it/s 1.8s0.2s
#                    all        100        291      0.625      0.605      0.636       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50     0.621G      1.385      2.773   0.006449         17        512: 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.7it/s 1.7s0.1s
#                    all        100        291      0.645      0.605      0.658      0.485
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50     0.621G      1.341      2.145   0.005555         33        512: 100% ━━━━━━━━━━━━ 25/25 5.2it/s 4.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.7it/s 1.7s0.1s
#                    all        100        291      0.604      0.636      0.649      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50     0.621G      1.216      2.376   0.005585          1        512: 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.9it/s 1.7s0.1s
#                    all        100        291      0.619       0.63      0.655      0.485
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50     0.621G       1.33      2.205   0.005904         11        512: 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.8it/s 1.7s0.1s
#                    all        100        291      0.623      0.677      0.686      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50     0.621G      1.347      2.205   0.006276          7        512: 100% ━━━━━━━━━━━━ 25/25 5.1it/s 4.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.9it/s 1.6s0.1s
#                    all        100        291      0.621       0.66      0.694      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50     0.621G      1.257      1.899    0.00531          9        512: 100% ━━━━━━━━━━━━ 25/25 4.8it/s 5.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.9it/s 1.7s0.1s
#                    all        100        291      0.651      0.649      0.702      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50     0.621G      1.258      2.192   0.005853         23        512: 100% ━━━━━━━━━━━━ 25/25 5.0it/s 5.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 8.0it/s 1.6s0.1s
#                    all        100        291       0.63      0.689      0.711      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50     0.621G      1.211      1.861   0.005229         18        512: 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 6.5it/s 2.0s0.2s
#                    all        100        291      0.662      0.677      0.718       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50     0.621G      1.342      2.021   0.005465          7        512: 100% ━━━━━━━━━━━━ 25/25 4.2it/s 6.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.3it/s 1.8s0.1s
#                    all        100        291      0.656      0.701      0.731       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50     0.625G      1.376      1.993   0.005471         17        512: 100% ━━━━━━━━━━━━ 25/25 5.0it/s 5.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 8.3it/s 1.6s0.1s
#                    all        100        291      0.677       0.67      0.733      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50     0.641G      1.258      1.802   0.005549         19        512: 100% ━━━━━━━━━━━━ 25/25 4.3it/s 5.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.5it/s 1.7s0.1s
#                    all        100        291       0.67      0.684      0.739      0.557
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50     0.641G      1.232      1.798   0.005893         13        512: 100% ━━━━━━━━━━━━ 25/25 5.3it/s 4.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.4it/s 1.7s0.1s
#                    all        100        291      0.666      0.732       0.75      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50     0.641G        1.2      1.966   0.005727          4        512: 100% ━━━━━━━━━━━━ 25/25 5.0it/s 5.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.8it/s 1.7s0.1s
#                    all        100        291      0.654      0.718      0.757      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50     0.641G      1.204      2.151    0.00579         17        512: 100% ━━━━━━━━━━━━ 25/25 5.4it/s 4.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 8.2it/s 1.6s0.1s
#                    all        100        291      0.634      0.729      0.755      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50     0.641G      1.302      1.916   0.006722          5        512: 100% ━━━━━━━━━━━━ 25/25 5.2it/s 4.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.4it/s 1.8s0.1s
#                    all        100        291      0.655      0.711      0.756      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50     0.641G      1.152      2.047   0.006129         10        512: 100% ━━━━━━━━━━━━ 25/25 5.3it/s 4.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.0it/s 1.9s0.1s
#                    all        100        291      0.646      0.704       0.76      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50     0.641G      1.209      1.934   0.005535         19        512: 100% ━━━━━━━━━━━━ 25/25 4.9it/s 5.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 8.1it/s 1.6s0.1s
#                    all        100        291      0.654       0.72      0.763       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50     0.641G      1.231      2.033   0.006413         18        512: 100% ━━━━━━━━━━━━ 25/25 5.0it/s 5.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.4it/s 1.7s0.1s
#                    all        100        291      0.657      0.749       0.77      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50     0.641G       1.19       1.78   0.005261          6        512: 100% ━━━━━━━━━━━━ 25/25 5.2it/s 4.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.3it/s 1.8s0.1s
#                    all        100        291      0.662      0.718      0.775      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50     0.641G      1.182      1.884   0.005387         10        512: 100% ━━━━━━━━━━━━ 25/25 5.0it/s 5.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 8.4it/s 1.5s0.1s
#                    all        100        291      0.683      0.732      0.778      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50     0.641G       1.18      1.956   0.006092          7        512: 100% ━━━━━━━━━━━━ 25/25 5.3it/s 4.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 7.8it/s 1.7s0.1s
#                    all        100        291      0.692      0.725      0.781      0.577
#
# 50 epochs completed in 0.110 hours.
# Optimizer stripped from D:\Main Projects\EfficientEyes\runs\detect\overfit_test7\weights\last.pt, 5.4MB
# Optimizer stripped from D:\Main Projects\EfficientEyes\runs\detect\overfit_test7\weights\best.pt, 5.4MB
#
# Validating D:\Main Projects\EfficientEyes\runs\detect\overfit_test7\weights\best.pt...
# Ultralytics 8.4.7  Python-3.12.6 torch-2.9.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLO26n summary (fused): 122 layers, 2,375,031 parameters, 0 gradients, 5.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 8.0it/s 1.6s0.1s
#                    all        100        291      0.692      0.726      0.781      0.577
# Speed: 0.4ms preprocess, 3.4ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to D:\Main Projects\EfficientEyes\runs\detect\overfit_test7

# %%
import torch
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available:  {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Name:        {torch.cuda.get_device_name(0)}")
else:
    print("❌ SYSTEM IS RUNNING ON CPU")
# Out:
# PyTorch Version: 2.9.0+cu130
# CUDA Available:  True
# GPU Name:        NVIDIA GeForce RTX 4060 Laptop GPU
